# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanJuradoS/UTP-IA-2025/blob/main/03_04_Missing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <a href='https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html'> <img src='https://www.python.org/static/img/python-logo.png' /></a>
# ___

# %% [markdown]
# # Missing Data (datos faltantes)
#
# Vamos a mostrar algunos métodos convenientes para lidiar con los datos faltantes en Pandas:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='PONER UN VALOR')
# Out:
#                 A               B  C
# 0               1               5  1
# 1               2  PONER UN VALOR  2
# 2  PONER UN VALOR  PONER UN VALOR  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# # Excelente trabajo!
